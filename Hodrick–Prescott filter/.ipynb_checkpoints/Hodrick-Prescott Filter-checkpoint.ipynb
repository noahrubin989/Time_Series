# %% [markdown]
# **Hodrick Prescott Filter/Decomposition**
#
# Noah Rubin
#
# Self study - December 2021
#
# *Note: Refer to my hp_filter_helper_functions.py file for the helper functions*

# %% [markdown]
# ---
# The Hodrick Prescott Filter is a data smoothing technique that aims to extract the trend $\tau_t$ and cyclical component $c_t$ from a time series $y_t$ such that $y_t = \tau_t + c_t$. It aims to remove short term fluctuations associated with the time series in an attempt to reveal the general long term trends, which can then assist with economic forecasting.
#
# ---
#
# The statsmodels implementation is based off an academic paper ["On Adjusting the Hodrick-Prescott Filter for the Frequency of Observations"](https://home.uchicago.edu/~huhlig/papers/uhlig.ravn.res.2002.pdf) by Morten O. Ravn and Harald Uhlig. The implementation aims to find the componenets of the $\vec{\hat \tau} = \begin{pmatrix}\hat{\tau}_1\\\hat{\tau}_2\\\hat{\tau}_3\\\vdots\\\hat{\tau}_T\end{pmatrix}$ column vector that minimises the quadratic loss function
#
# $$\min_{\\{ \tau_{t}\\} }\sum_{t=1}^{T}c_{t}^{2}+\lambda\sum_{t=1}^{T}\left[\left(\tau_{t+1}-\tau_{t}\right)-\left(\tau_{t}-\tau_{t-1}\right)\right]^{2}$$
#
# whereby $c_t^2 = (y_t - \tau_t)^2$ represents the squared deviations of the trend component from the actual values which penalises the cyclical component $c_t$. The $\lambda$ constant is a positive scalar multiple which penalises variability in the trend component series to encourage data smoothing. The larger the value of $\lambda$, the smoother is the solution series. As $\lambda \to \infty$, the trend acceleration approaches towards 0, resulting a line representing a least squares fit to the data. Based off suggestions made by Ravn and Uhlig in their paper (linked above and below), statsmodels suggests to use a $\lambda$ value of 6.25 for annual data, 1600 for quarterly data and 129600 for monthly data. For other time periods, using the HP filter might not be the best option.
#
# ---
#
# For a (finite) sample of size $T$ our $\vec{\hat\tau}$ vector can be obtained through computing
#
# $$\vec{\hat\tau} = (I_T + \lambda K^TK)^{-1}\vec{y}$$
#
# whereby statsmodels defines $I_T$ as an identity matrix that has dimension $T \times T$, where $T$ is the number of rows in the dataset. The matrix $K$ is a $(T - 2) \times T$ matrix that has the following properties:
#
# * $K_{ij} = -2$ when $i = j + 1$
# * $K_{ij} = 1$ in cases where $i = j$ or $i = j + 2$
# * $K_{ij} = 0$ everywhere else
#
# where $K_{ij}$ represents row $i$, column $j$ in our matrix $K$
#
# Computing $K^T K$ ensures a $T \times T$ matrix, which means that we are able to add this matrix to $I_T$. The fact that this $K^TK$ matrix is square ensures that $(I + K^TK)$ is also square, hence we can find an inverse (it exists). The presence of many zeroes in the $K$ matrix makes this a [sparse matrix](https://machinelearningmastery.com/sparse-matrices-for-machine-learning/), which can be space inefficient for larger sample sizes. Since $\vec{\hat\tau} = (I_T + \lambda K^TK)^{-1}\vec{y} $  is a process of multiplying a matrix and a vector toghether, by matrix multiplication laws, each component of the trend estimate vector can be computed through a weighted sum whereby
#
# $$\hat{\tau}_i = \sum_{j=1}^T p_{ij}y_j$$
#
# in which $p_{ij}$ represents row $i$, column $j$ in the $(I_T + \lambda K^TK)^{-1}$ matrix. Since $\hat{c}_i = (y_i - \hat{\tau}_i)$ is computed based off our trend estimates, the vector of estimated cyclical components of the time series can also be viewed as a weighted sum of the individual values $y_i$ in our time series.
#
# ---
#
# While the Hodrick Prescott Filter is a popular tool to extract the estimated trend and cyclical component of a time series, there are sources, such as [this one](https://econweb.ucsd.edu/~jhamilto/hp.pdf) that accentuate potential drawbacks to using this filter
#
# ---
#
# Sources Used:
# * [Original Paper By Hodrick & Prescott](https://www0.gsb.columbia.edu/faculty/rhodrick/prescott-hodrick1997.pdf)
# * [University of York Publication](https://eprints.whiterose.ac.uk/97954/1/HP_ACM.pdf)
# * [The paper that statsmodels bases its implementation off](https://home.uchicago.edu/~huhlig/papers/uhlig.ravn.res.2002.pdf)
# * [Mathworks](https://www.mathworks.com/help/econ/hpfilter.html)
# * [Statsmodels documentation](https://www.statsmodels.org/dev/generated/statsmodels.tsa.filters.hp_filter.hpfilter.html)
# * [Source code](https://www.statsmodels.org/0.8.0/_modules/statsmodels/tsa/filters/hp_filter.html)
# * [Wikipedia Article](https://en.wikipedia.org/wiki/Hodrick%E2%80%93Prescott_filter)
# * [Drawbacks of the Hodrick-Prescott filter](https://econweb.ucsd.edu/~jhamilto/hp.pdf)
#
#
# Implementation Below ⬇️

# %%
import hp_filter_helper_functions as helper_funcs

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from statsmodels.tsa.filters.hp_filter import hpfilter

# For clear plots
# %matplotlib inline

# If running these cells locally, comment out the line above and uncomment the line below (much clearer plots)
# %config InlineBackend.figure_format = 'svg'

# So that any changes to .py files get updated here too
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# **Read in Data**
#
# Data obtained from [World Bank](https://data.worldbank.org/indicator/NY.GDP.PCAP.CD)

# %%
df = pd.read_csv('gdp_cap.csv')
df.head(20)
# Out:
#                    Country Name Country Code                Indicator Name  \
# 0                         Aruba          ABW  GDP per capita (current US$)
# 1   Africa Eastern and Southern          AFE  GDP per capita (current US$)
# 2                   Afghanistan          AFG  GDP per capita (current US$)
# 3    Africa Western and Central          AFW  GDP per capita (current US$)
# 4                        Angola          AGO  GDP per capita (current US$)
# 5                       Albania          ALB  GDP per capita (current US$)
# 6                       Andorra          AND  GDP per capita (current US$)
# 7                    Arab World          ARB  GDP per capita (current US$)
# 8          United Arab Emirates          ARE  GDP per capita (current US$)
# 9                     Argentina          ARG  GDP per capita (current US$)
# 10                      Armenia          ARM  GDP per capita (current US$)
# 11               American Samoa          ASM  GDP per capita (current US$)
# 12          Antigua and Barbuda          ATG  GDP per capita (current US$)
# 13                    Australia          AUS  GDP per capita (current US$)
# 14                      Austria          AUT  GDP per capita (current US$)
# 15                   Azerbaijan          AZE  GDP per capita (current US$)
# 16                      Burundi          BDI  GDP per capita (current US$)
# 17                      Belgium          BEL  GDP per capita (current US$)
# 18                        Benin          BEN  GDP per capita (current US$)
# 19                 Burkina Faso          BFA  GDP per capita (current US$)
#
#     Indicator Code         1960         1961         1962         1963  \
# 0   NY.GDP.PCAP.CD          NaN          NaN          NaN          NaN
# 1   NY.GDP.PCAP.CD   147.507808   146.910908   156.078705   182.115000
# 2   NY.GDP.PCAP.CD    59.773234    59.860900    58.458009    78.706429
# 3   NY.GDP.PCAP.CD   107.932233   113.081647   118.831107   123.442888
# 4   NY.GDP.PCAP.CD          NaN          NaN          NaN          NaN
# 5   NY.GDP.PCAP.CD          NaN          NaN          NaN          NaN
# 6   NY.GDP.PCAP.CD          NaN          NaN          NaN          NaN
# 7   NY.GDP.PCAP.CD          NaN          NaN          NaN          NaN
# 8   NY.GDP.PCAP.CD          NaN          NaN          NaN          NaN
# 9   NY.GDP.PCAP.CD          NaN          NaN  1155.890717   850.304579
# 10  NY.GDP.PCAP.CD          NaN          NaN          NaN          NaN
# 11  NY.GDP.PCAP.CD          NaN          NaN          NaN          NaN
# 12  NY.GDP.PCAP.CD          NaN          NaN          NaN          NaN
# 13  NY.GDP.PCAP.CD  1810.619230  1877.616638  1854.656834  1967.116537
# 14  NY.GDP.PCAP.CD   935.460427  1031.815004  1087.834243  1167.000532
# 15  NY.GDP.PCAP.CD          NaN          NaN          NaN          NaN
# 16  NY.GDP.PCAP.CD    70.051910    71.167188    73.435331    78.514621
# 17  NY.GDP.PCAP.CD  1273.691659  1350.197673  1438.523233  1535.023729
# 18  NY.GDP.PCAP.CD    93.022700    95.572232    94.464497    99.858918
# 19  NY.GDP.PCAP.CD    68.424734    71.558180    76.520549    78.372196
#
#            1964         1965  ...          2011          2012          2013  \
# 0           NaN          NaN  ...  24985.013920  24712.493260  26441.619940
# 1    162.232750   180.087426  ...   1769.483634   1734.938417   1712.686908
# 2     82.095307   101.108325  ...    591.190030    638.845852    624.315454
# 3    131.854402   138.526332  ...   1862.308267   1965.118485   2157.481149
# 4           NaN          NaN  ...   4615.468219   5100.097027   5254.881126
# 5           NaN          NaN  ...   4437.142612   4247.630047   4413.062005
# 6           NaN          NaN  ...  43334.811410  38686.461260  39540.724810
# 7           NaN          NaN  ...   6860.797659   7347.095720   7341.432905
# 8           NaN          NaN  ...  39194.672240  40976.490750  42412.639500
# 9   1173.238105  1279.113778  ...  12848.864200  13082.664330  13080.254730
# 10          NaN          NaN  ...   3525.807198   3681.844691   3838.173880
# 11          NaN          NaN  ...  10223.298360  11496.524100  11450.724200
# 12          NaN          NaN  ...  12746.633470  13272.734940  12910.590630
# 13  2131.377948  2281.098797  ...  62574.145700  68027.841710  68156.627920
# 14  1269.412583  1374.532140  ...  51374.958410  48567.695290  50716.708710
# 15          NaN          NaN  ...   7189.691229   7496.294648   7875.756953
# 16    86.161550    51.381881  ...    249.577979    252.358871    256.975653
# 17  1701.846276  1835.594766  ...  47348.525020  44673.115880  46744.662540
# 18   104.339929   110.132585  ...   1130.273251   1145.140105   1251.209767
# 19    80.472718    81.725052  ...    751.172770    758.000427    787.469438
#
#             2014          2015          2016          2017          2018  \
# 0   26893.011510  28396.908420  28452.170610  29350.805020  30253.279360
# 1    1701.765354   1546.877709   1429.596045   1571.307053   1573.221585
# 2     614.223342    556.007221    512.012778    516.679862    485.668419
# 3    2178.368454   1894.310195   1673.835527   1613.473553   1704.139603
# 4    5408.411700   4166.979833   3506.073128   4095.810057   3289.643995
# 5    4578.633208   3952.802538   4124.055390   4531.019374   5287.663694
# 6   41303.929370  35770.776700  37475.635060  38964.904480  41791.969840
# 7    7266.334447   6191.492876   5942.345112   5959.738018   6473.549536
# 8   43751.805650  38663.400500  38141.867130  40644.791190  43839.324490
# 9   12334.798250  13789.060420  12790.242470  14613.041820  11795.159390
# 10   3986.231624   3607.289299   3591.828052   3914.527854   4220.540321
# 11  11525.156390  12059.635160  12038.249700  11003.829760  11521.609780
# 12  13501.580920  14285.329780  15198.742970  15383.576400  16679.591660
# 13  62511.690590  56707.022080  49881.763710  53934.250180  57180.779400
# 14  51717.495940  44178.047380  45276.831440  47312.006230  51461.433220
# 15   7891.313147   5500.310382   3880.738731   4147.089716   4739.841710
# 16    274.857836    305.549652    260.565221    253.826354    238.783467
# 17  47700.540360  40991.808140  41984.103030  44089.310090  47519.553100
# 18   1291.410185   1076.796698   1087.287331   1136.593872   1241.825298
# 19    792.846237    653.327268    688.250696    734.996268    804.500538
#
#             2019          2020
# 0            NaN           NaN
# 1    1527.734558   1356.699267
# 2     494.179350    516.747871
# 3    1777.918672   1710.073363
# 4    2809.626088   1776.166868
# 5    5395.659532   5246.292306
# 6   40897.330870           NaN
# 7    6458.043878   5586.781783
# 8   42701.443050  36284.555240
# 9   10056.637940   8579.017773
# 10   4604.646324   4266.018074
# 11  11715.360140  12844.900990
# 12  17376.649680  13992.744480
# 13  54875.285960  51692.842750
# 14  50114.401110  48586.801320
# 15   4805.753718   4221.407478
# 16    228.213589    238.990726
# 17  46591.491610  45159.348220
# 18   1219.515506   1291.040972
# 19    796.115207    857.932730
#
# [20 rows x 65 columns]

# %% [markdown]
# **No need to keep country code and indicator name/code**

# %%
df.drop(['Country Code', 'Indicator Name', 'Indicator Code'], axis='columns', inplace=True)

# %% [markdown]
# **Tidy Data**
#
# Definitions of a tidy dataset can be subjective at times, though most people would agree on the fact that tidy data normally displays the following characteristics
#
# * Each variable has its own column.
# * Each observation is its own row.
# * Each value must have its own cell
#
# According to [Hadley Wickam](http://hadley.nz/) (a major contributer to various packages in the R programming language):
# * There’s a general advantage to picking one consistent way of storing data. If you have a consistent data structure, it’s easier to learn the tools that work with it because they have an underlying uniformity
# * Tidy datasets are easy to manipulate, model and visualise, and have a specific structure
# * Tidy datasets provide a standardised way to link the structure of a dataset (its physical layout)
# with its semantics (its meaning).
#
# ---
#
# In this dataset, we have year values representing column names, though it'd be more suitable to have it placed all under one variable called 'Year'
#
# [Academic paper on tidy data](https://vita.had.co.nz/papers/tidy-data.pdf)

# %%
df = df.melt(id_vars=['Country Name'], var_name='Year', value_name='GDP Per Capita')
df.head(30)  # better
# Out:
#                    Country Name  Year  GDP Per Capita
# 0                         Aruba  1960             NaN
# 1   Africa Eastern and Southern  1960      147.507808
# 2                   Afghanistan  1960       59.773234
# 3    Africa Western and Central  1960      107.932233
# 4                        Angola  1960             NaN
# 5                       Albania  1960             NaN
# 6                       Andorra  1960             NaN
# 7                    Arab World  1960             NaN
# 8          United Arab Emirates  1960             NaN
# 9                     Argentina  1960             NaN
# 10                      Armenia  1960             NaN
# 11               American Samoa  1960             NaN
# 12          Antigua and Barbuda  1960             NaN
# 13                    Australia  1960     1810.619230
# 14                      Austria  1960      935.460427
# 15                   Azerbaijan  1960             NaN
# 16                      Burundi  1960       70.051910
# 17                      Belgium  1960     1273.691659
# 18                        Benin  1960       93.022700
# 19                 Burkina Faso  1960       68.424734
# 20                   Bangladesh  1960       89.035239
# 21                     Bulgaria  1960             NaN
# 22                      Bahrain  1960             NaN
# 23                 Bahamas, The  1960     1550.267699
# 24       Bosnia and Herzegovina  1960             NaN
# 25                      Belarus  1960             NaN
# 26                       Belize  1960      304.903860
# 27                      Bermuda  1960     1902.402119
# 28                      Bolivia  1960      102.237722
# 29                       Brazil  1960             NaN

# %% [markdown]
# **Change year (strings) to a date column**
#
#
# Will be assuming the years are representing the end of the calendar year

# %%
df['Year'] = df.Year.apply(lambda x: pd.to_datetime(f"31-12-{x}"))

# %% [markdown]
# **To capture the estimated trend and cyclical component, all values will need to be present in the time series**
#
# Filter only countries where all values from 1960-2020 are captured

# %%
df = helper_funcs.filter_relevant_countries(df)
np.sort(df['Country Name'].unique())  # These countries/regions had all values present for GDP per capita
# Out:
# array(['Africa Eastern and Southern', 'Africa Western and Central',
#        'Algeria', 'Australia', 'Austria', 'Bahamas, The', 'Bangladesh',
#        'Belgium', 'Belize', 'Benin', 'Bermuda', 'Bolivia', 'Botswana',
#        'Burkina Faso', 'Burundi', 'Cameroon', 'Canada',
#        'Caribbean small states', 'Central African Republic', 'Chad',
#        'Chile', 'China', 'Colombia', 'Congo, Dem. Rep.', 'Congo, Rep.',
#        'Costa Rica', "Cote d'Ivoire", 'Dominican Republic',
#        'Early-demographic dividend', 'East Asia & Pacific',
#        'East Asia & Pacific (IDA & IBRD countries)',
#        'East Asia & Pacific (excluding high income)', 'Ecuador',
#        'Eswatini', 'Euro area', 'Fiji', 'Finland', 'France', 'Gabon',
#        'Ghana', 'Greece', 'Guatemala', 'Guyana', 'Haiti',
#        'Heavily indebted poor countries (HIPC)', 'High income',
#        'Honduras', 'Hong Kong SAR, China', 'IBRD only',
#        'IDA & IBRD total', 'IDA blend', 'IDA only', 'IDA total',
#        'Iceland', 'India', 'Ireland', 'Italy', 'Jamaica', 'Japan',
#        'Kenya', 'Korea, Rep.', 'Late-demographic dividend', 'Lesotho',
#        'Low & middle income', 'Lower middle income', 'Luxembourg',
#        'Madagascar', 'Malawi', 'Malaysia', 'Mexico', 'Middle income',
#        'Morocco', 'Nepal', 'Netherlands', 'Nicaragua', 'Niger', 'Nigeria',
#        'North America', 'Norway', 'OECD members', 'Pakistan', 'Panama',
#        'Papua New Guinea', 'Peru', 'Philippines', 'Portugal',
#        'Post-demographic dividend', 'Pre-demographic dividend',
#        'Puerto Rico', 'Rwanda', 'Senegal', 'Seychelles', 'Sierra Leone',
#        'Singapore', 'South Africa', 'South Asia',
#        'South Asia (IDA & IBRD)', 'Spain', 'Sri Lanka',
#        'St. Kitts and Nevis', 'St. Vincent and the Grenadines',
#        'Sub-Saharan Africa', 'Sub-Saharan Africa (IDA & IBRD countries)',
#        'Sub-Saharan Africa (excluding high income)', 'Sudan', 'Suriname',
#        'Sweden', 'Thailand', 'Togo', 'Trinidad and Tobago', 'Turkey',
#        'Uganda', 'United Kingdom', 'United States', 'Upper middle income',
#        'Uruguay', 'World', 'Zambia', 'Zimbabwe'], dtype=object)

# %% [markdown]
# **Apply the filter**

# %%
# helper_funcs.apply_hp_filter(df, 'South Africa', column='GDP Per Capita', lamb=6.25)

# # If you wanted to plot many places at the same time:
# # ===================================================

areas_of_interest = [
    'Australia',
    'France',
    'Hong Kong SAR, China',
    'Italy',
    'Japan',
    'Luxembourg',
    'South Africa',
    'Sweden',
    'United Kingdom',
    'United States',
    'World',
    'Zimbabwe'
]

for area in areas_of_interest:
    helper_funcs.apply_hp_filter(df, area, column='GDP Per Capita', lamb=6.25)
